# %% [markdown]
# # INTRODUCTION
# * Churn: 1 jika customer membatalkan layanan, 0 sebaliknya
# * AccountWeeks: jumlah minggu pelanggan memiliki akun aktif
# * ContractRenewal: 1 jika pelanggan baru saja memperbarui kontrak, 0 sebaliknya
# * DataPlan: 1 jika pelanggan punya paket, 0 sebaliknya
# * DataUsage: gigabyte penggunaan data bulanan
# * CustServCalls:jumlah panggilan kecustomer service
# * DayMins: rata-rata daytime minutes dalam sebulan
# * DayCalls: jumlah rata-rata daycalls
# * MonthlyCharge: tagihan bulanan rata-rata
# * OverageFee: biaya overage terbesar dalam 12 bulan terakhir
# * RoamMins: jumlah rata-rata menit roaming

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Import Data

# %%
df = pd.read_csv('telecom_churn.csv')
df.head()
# Out:
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# 1    161.6       123           82.0        9.78      13.7
# 2    243.4       114           52.0        6.06      12.2
# 3    299.4        71           57.0        3.10       6.6
# 4    166.7       113           41.0        7.42      10.1

# %% [markdown]
# # EDA & Visualisasi

# %%
df.shape
# Out:
# (3333, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Churn            3333 non-null   int64
#  1   AccountWeeks     3333 non-null   int64
#  2   ContractRenewal  3333 non-null   int64
#  3   DataPlan         3333 non-null   int64
#  4   DataUsage        3333 non-null   float64
#  5   CustServCalls    3333 non-null   int64
#  6   DayMins          3333 non-null   float64
#  7   DayCalls         3333 non-null   int64
#  8   MonthlyCharge    3333 non-null   float64
#  9   OverageFee       3333 non-null   float64
#  10  RoamMins         3333 non-null   float64
# dtypes: float64(5), int64(6)
# memory usage: 286.6 KB

# %% [markdown]
# Data tidak memiliki missing value dan tipe data sudah sesuai

# %%
df.describe()
# Out:
#              Churn  AccountWeeks  ContractRenewal     DataPlan    DataUsage  \
# count  3333.000000   3333.000000      3333.000000  3333.000000  3333.000000
# mean      0.144914    101.064806         0.903090     0.276628     0.816475
# std       0.352067     39.822106         0.295879     0.447398     1.272668
# min       0.000000      1.000000         0.000000     0.000000     0.000000
# 25%       0.000000     74.000000         1.000000     0.000000     0.000000
# 50%       0.000000    101.000000         1.000000     0.000000     0.000000
# 75%       0.000000    127.000000         1.000000     1.000000     1.780000
# max       1.000000    243.000000         1.000000     1.000000     5.400000
#
#        CustServCalls      DayMins     DayCalls  MonthlyCharge   OverageFee  \
# count    3333.000000  3333.000000  3333.000000    3333.000000  3333.000000
# mean        1.562856   179.775098   100.435644      56.305161    10.051488
# std         1.315491    54.467389    20.069084      16.426032     2.535712
# min         0.000000     0.000000     0.000000      14.000000     0.000000
# 25%         1.000000   143.700000    87.000000      45.000000     8.330000
# 50%         1.000000   179.400000   101.000000      53.500000    10.070000
# 75%         2.000000   216.400000   114.000000      66.200000    11.770000
# max         9.000000   350.800000   165.000000     111.300000    18.190000
#
#           RoamMins
# count  3333.000000
# mean     10.237294
# std       2.791840
# min       0.000000
# 25%       8.500000
# 50%      10.300000
# 75%      12.100000
# max      20.000000

# %%
def vis_univar(data, column):
    sns.color_palette("pastel")
    fig, (ax_box, ax_hist) = plt.subplots(2, sharex = True, gridspec_kw = {'height_ratios':(.2, .8)})
    
    sns.boxplot(data = df, x = column, ax = ax_box)
    sns.histplot(data = df, x = column, ax = ax_hist)
    
    ax_box.set(xlabel = '')
    ax_hist.set(ylabel = 'Histogram (Count)')
    
    plt.show()

# %%
vis_univar(df, 'DayCalls')

# %%
df.loc[(df['DayCalls'] < 25)]
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 1345      1            98                1         0        0.0
# 1397      0           101                1         0        0.3
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 1345              4      0.0         0           14.0        7.98       6.8
# 1397              1      0.0         0           20.0        9.61       7.2

# %%
df.loc[df['DayCalls'] == 0]
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 1345      1            98                1         0        0.0
# 1397      0           101                1         0        0.3
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 1345              4      0.0         0           14.0        7.98       6.8
# 1397              1      0.0         0           20.0        9.61       7.2

# %% [markdown]
# Berdasarkan boxplot terdapat outlier pada kolom 'DayCalls' dimana terdapat 2 customer yang memiliki rata-rata telfon harian = 0 namun sudah berlangganan selama beberapa minggu dan membayar sewa bulanan. Oleh karena itu, kita dapat menghilangkannya.

# %%
df = df[df['DayCalls'] != 0].reset_index(drop = True)
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1       2.70
# 1         0           107                1         1       3.70
# 2         0           137                1         0       0.00
# 3         0            84                0         0       0.00
# 4         0            75                0         0       0.00
# ...     ...           ...              ...       ...        ...
# 3326      0           192                1         1       2.67
# 3327      0            68                1         0       0.34
# 3328      0            28                1         0       0.00
# 3329      0           184                0         0       0.00
# 3330      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1    265.1       110           89.0        9.87      10.0
# 1                 1    161.6       123           82.0        9.78      13.7
# 2                 0    243.4       114           52.0        6.06      12.2
# 3                 2    299.4        71           57.0        3.10       6.6
# 4                 3    166.7       113           41.0        7.42      10.1
# ...             ...      ...       ...            ...         ...       ...
# 3326              2    156.2        77           71.7       10.78       9.9
# 3327              3    231.1        57           56.4        7.67       9.6
# 3328              2    180.8       109           56.0       14.44      14.1
# 3329              2    213.8       105           50.0        7.98       5.0
# 3330              0    234.4       113          100.0       13.30      13.7
#
# [3331 rows x 11 columns]

# %%
vis_univar(df, 'OverageFee')

# %%
df.loc[(df['OverageFee'] < 1.25)]
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 2930      0            97                1         0        0.0
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 2930              1    209.2       134           36.0         0.0      11.8

# %% [markdown]
# Berdasarkan boxplot terdapat outlier pada kolom 'OverageFee' dimana terdapat 1 customer yang memiliki biaya langganan
# tebesar yang dikeluarkan selama berlangganan = 0, padahal customer sudah berlangganan selama beberapa minggu dan
# membayar sewa bulanan. Oleh karena itu, kita dapat menghilangkannya.

# %%
df = df[df['OverageFee'] != 0].reset_index(drop = True)
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1       2.70
# 1         0           107                1         1       3.70
# 2         0           137                1         0       0.00
# 3         0            84                0         0       0.00
# 4         0            75                0         0       0.00
# ...     ...           ...              ...       ...        ...
# 3325      0           192                1         1       2.67
# 3326      0            68                1         0       0.34
# 3327      0            28                1         0       0.00
# 3328      0           184                0         0       0.00
# 3329      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1    265.1       110           89.0        9.87      10.0
# 1                 1    161.6       123           82.0        9.78      13.7
# 2                 0    243.4       114           52.0        6.06      12.2
# 3                 2    299.4        71           57.0        3.10       6.6
# 4                 3    166.7       113           41.0        7.42      10.1
# ...             ...      ...       ...            ...         ...       ...
# 3325              2    156.2        77           71.7       10.78       9.9
# 3326              3    231.1        57           56.4        7.67       9.6
# 3327              2    180.8       109           56.0       14.44      14.1
# 3328              2    213.8       105           50.0        7.98       5.0
# 3329              0    234.4       113          100.0       13.30      13.7
#
# [3330 rows x 11 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# tidak ada data duplicate

# %%
labels = 'Churned', "Retained"
sizes = [df.Churn[df['Churn'] == 1].count(), df.Churn[df['Churn'] == 0].count()]
explode = (0.1, 0)

fig1, ax1 = plt.subplots(figsize=(6, 4))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')

plt.title("Ratio of Customer Churned & Retained")

plt.show()

# %% [markdown]
# Perbandingan customer yang membatalkan layanan telekomunikasi lebih kecil dibandingkan dengan yang masih tetap memakai servis telekomunikasi. Sehingga perusahaan masih bisa mempertahankan customer yang sudah ada.

# %%
ax = plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
sns.countplot(data = df , x = "ContractRenewal" , palette="Blues", edgecolor='w')
plt.title("Barchart of Contract Renewal" , size=15, fontweight='bold', fontfamily='monospace')
plt.xlabel("Contract Renewal", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel('')

plt.subplot(2,2,2)
sns.countplot(data = df , x = "DataPlan" , palette="Blues", edgecolor='w')
plt.title("Barchart of Data Plan" , size=15, fontweight='bold', fontfamily='monospace')
plt.xlabel("Data Plan", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel('')

plt.subplot(2,2,(3,4))
sns.countplot(data = df , x = "CustServCalls" , palette="Blues", edgecolor='w')
plt.title("Barchart ofCustomer Service Calls Renewal" , size=15, fontweight='bold', fontfamily='monospace')
plt.xlabel("Customer Service Calls Renewal", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel('')
plt.tight_layout()

plt.show()

# %% [markdown]
# Berdasarkan bar chart disamping, diketahui bahwa :
# * Customer yang memperbarui kontrak dengan layanan telekomunikasi lebih banyak sekitar 3000 orang dibanding yang tidak memperbarui kontrak.
# * Customer lebih banyak tidak memakai paket data yang berjumlah sekitar 2400
# * Customer paling banyak melakukan panggilan customer service dalam 1 kali panggilan

# %%
sns.boxplot(x='Churn',y='CustServCalls', data=df)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='CustServCalls'>

# %%
sns.boxplot(x='Churn',y='OverageFee', data=df)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='OverageFee'>

# %%
sns.scatterplot(x='OverageFee',y='MonthlyCharge', hue='Churn', data=df)
# Out:
# <AxesSubplot:xlabel='OverageFee', ylabel='MonthlyCharge'>

# %%
df.corr('spearman')
# Out:
#                     Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# Churn            1.000000      0.015650        -0.260266 -0.101963  -0.101608
# AccountWeeks     0.015650      1.000000        -0.029530  0.008700   0.016752
# ContractRenewal -0.260266     -0.029530         1.000000 -0.005825  -0.010375
# DataPlan        -0.101963      0.008700        -0.005825  1.000000   0.841460
# DataUsage       -0.101608      0.016752        -0.010375  0.841460   1.000000
# CustServCalls    0.135571     -0.005929         0.030261 -0.022031  -0.017501
# DayMins          0.172107      0.017880        -0.049375  0.002473  -0.004304
# DayCalls         0.027612      0.032762        -0.012873 -0.013025  -0.019274
# MonthlyCharge    0.095740      0.011696        -0.044220  0.695705   0.646936
# OverageFee       0.089233     -0.008040        -0.010111  0.022220   0.010829
# RoamMins         0.061870      0.014754        -0.043679 -0.004837   0.076794
#
#                  CustServCalls   DayMins  DayCalls  MonthlyCharge  OverageFee  \
# Churn                 0.135571  0.172107  0.027612       0.095740    0.089233
# AccountWeeks         -0.005929  0.017880  0.032762       0.011696   -0.008040
# ContractRenewal       0.030261 -0.049375 -0.012873      -0.044220   -0.010111
# DataPlan             -0.022031  0.002473 -0.013025       0.695705    0.022220
# DataUsage            -0.017501 -0.004304 -0.019274       0.646936    0.010829
# CustServCalls         1.000000 -0.014343 -0.020179      -0.025008   -0.017582
# DayMins              -0.014343  1.000000  0.007275       0.598671    0.006112
# DayCalls             -0.020179  0.007275  1.000000      -0.010150   -0.013934
# MonthlyCharge        -0.025008  0.598671 -0.010150       1.000000    0.288312
# OverageFee           -0.017582  0.006112 -0.013934       0.288312    1.000000
# RoamMins             -0.016810 -0.017663  0.013430       0.054627   -0.003356
#
#                  RoamMins
# Churn            0.061870
# AccountWeeks     0.014754
# ContractRenewal -0.043679
# DataPlan        -0.004837
# DataUsage        0.076794
# CustServCalls   -0.016810
# DayMins         -0.017663
# DayCalls         0.013430
# MonthlyCharge    0.054627
# OverageFee      -0.003356
# RoamMins         1.000000

# %%
plt.figure(figsize = (10, 8))
corr = df.corr(method='spearman')
mask = np.triu(np.ones_like(corr, dtype=bool))
cormat = sns.heatmap(corr, annot=True, cmap='viridis', linewidths=1, fmt=".2f")
cormat.set_title('Correlation Matrix')
plt.show()

# %%
df.corr('pearson')
# Out:
#                     Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# Churn            1.000000      0.016600        -0.260266 -0.101963  -0.086950
# AccountWeeks     0.016600      1.000000        -0.024718  0.002885   0.014358
# ContractRenewal -0.260266     -0.024718         1.000000 -0.005825  -0.019060
# DataPlan        -0.101963      0.002885        -0.005825  1.000000   0.945971
# DataUsage       -0.086950      0.014358        -0.019060  0.945971   1.000000
# CustServCalls    0.207606     -0.003769         0.024439 -0.017652  -0.021516
# DayMins          0.208102      0.006175        -0.048964 -0.002820   0.002249
# DayCalls         0.021892      0.038712        -0.002958 -0.012738  -0.009290
# MonthlyCharge    0.073979      0.012507        -0.046793  0.737945   0.782307
# OverageFee       0.093214     -0.006907        -0.018664  0.020660   0.018744
# RoamMins         0.069167      0.009506        -0.045721 -0.001646   0.162581
#
#                  CustServCalls   DayMins  DayCalls  MonthlyCharge  OverageFee  \
# Churn                 0.207606  0.208102  0.021892       0.073979    0.093214
# AccountWeeks         -0.003769  0.006175  0.038712       0.012507   -0.006907
# ContractRenewal       0.024439 -0.048964 -0.002958      -0.046793   -0.018664
# DataPlan             -0.017652 -0.002820 -0.012738       0.737945    0.020660
# DataUsage            -0.021516  0.002249 -0.009290       0.782307    0.018744
# CustServCalls         1.000000 -0.011989 -0.016729      -0.027095   -0.013081
# DayMins              -0.011989  1.000000 -0.003479       0.566412    0.006735
# DayCalls             -0.016729 -0.003479  1.000000      -0.014681   -0.021172
# MonthlyCharge        -0.027095  0.566412 -0.014681       1.000000    0.280788
# OverageFee           -0.013081  0.006735 -0.021172       0.280788    1.000000
# RoamMins             -0.009032 -0.012591  0.017950       0.116246   -0.010748
#
#                  RoamMins
# Churn            0.069167
# AccountWeeks     0.009506
# ContractRenewal -0.045721
# DataPlan        -0.001646
# DataUsage        0.162581
# CustServCalls   -0.009032
# DayMins         -0.012591
# DayCalls         0.017950
# MonthlyCharge    0.116246
# OverageFee      -0.010748
# RoamMins         1.000000

# %%
plt.figure(figsize = (10, 8))
corr = df.corr(method='pearson')
mask = np.triu(np.ones_like(corr, dtype=bool))
cormat = sns.heatmap(corr, annot=True, cmap='viridis', linewidths=1, fmt=".2f")
cormat.set_title('Correlation Matrix')
plt.show()

# %% [markdown]
# Dapat dilihat bahwa variabel yang memiliki korelasi tinggi adalah 'MonthlyCharge', 'DataPlan', dan 'DataUsage'. Hal ini dikarenakan nilai korelasi bernilai positif dan tinggi mendekati angka 1
#
# Korelasi paling kuat antara variabel :
# *  Data Usage dengan Data Plan
# * Data plan dengan Monthly Charge
# * Data usage dengan Monthly Charge
# Korelasi cukup kuat antara variabel
# * DayMins dengan Monthly Charge

# %%
sns.pairplot(df, hue="Churn")

# %% [markdown]
# Hal-hal yang terlihat dari pair plot diatas
#
# * DataUsage memiliki hubungan linier dengan RoamMins untuk yang bukan 0. Ini perlu penyelidikan lebih lanjut untuk melihat apakah kita bisa menggunakan salah satu variabel saja.
# * MonthlyCharge memiliki hubungan positif dengan DataUsage, DayMins, dan OverageFee

# %%
fig, axarr = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(x='DataPlan', hue = 'Churn',data = df, ax=axarr[0], palette="pastel")
sns.countplot(x='ContractRenewal', hue = 'Churn',data = df, ax=axarr[1], palette="pastel")
# Out:
# <AxesSubplot:xlabel='ContractRenewal', ylabel='count'>

# %% [markdown]
# * Berdasarkan hasil diatas, diketahui bahwa pelanggan yang tidak mempunyai paket data plan lebih banyak yang melakukan churn dibanding pelanggan yang mempunyai paket data
# * ContractRenewal, pelanggan yang melakukan pembaruan kontrak lebih banyak melakukan churn dibanding tidak melakukan pembaruan kontrak.

# %%
def piecharts (df, cat_variables, n_rows=None, n_cols=None, hue="Churn"):
    fig=plt.figure(figsize=(18,10))
    explode = (0, 0.1)
    labels=['Churned', 'Retained']
    for i, var in enumerate(cat_variables):
        df_0 = [len(df[(df[var]==0) & (df[hue]==1)]), len(df[(df[var]==0) & (df[hue]==0)])] #when the cat_var == 0
        
        ax0=fig.add_subplot(n_rows, n_cols, i+1)
        ax0.pie(df_0, explode=explode, labels=labels, autopct='%1.1f%%')
        ax0.set_title("Do not have {}".format(var))
        
    for i, var in enumerate(cat_variables):
        df_1 = [len(df[(df[var]!=0) & (df[hue]==1)]), len(df[(df[var]!=0) & (df[hue]==0)])] #when the cat_var == 1
        
        ax1=fig.add_subplot(n_rows, n_cols, i+1+n_rows)
        ax1.pie(df_1, explode=explode, labels=labels, autopct='%1.1f%%')
        ax1.set_title("Have {}".format(var))
    plt.show()

# %%
cat_variables = df[["DataPlan", "ContractRenewal", "DataUsage"]] 

piecharts(df, cat_variables, 3, 3)

# %% [markdown]
# * Pelanggan yang tidak mempunyai data plan lebih banyak melakukan churn dibanding yang mempunyai data plan
# * Pelanggan yang tidak melakukan contract renewal lebih banyak melakukan churn dibanding yang tidak melakukan contract renewal
# * Pelanggan yang tidak menggunakan data sama sekali memiliki tingkat churn 7% lebih besar. Ini bisa membantu kita dalam perdiksi

# %%
fig = plt.subplots()
sns.boxplot(x='DataPlan', y="DayMins", hue = 'Churn', data = df, palette="pastel")
# Out:
# <AxesSubplot:xlabel='DataPlan', ylabel='DayMins'>

# %% [markdown]
# Rata-rata, orang yang tidak membeli paket data dan DayMinsnya sangat tinggi sehingga sangat mungkin pelanggan untuk melakukan churn.

# %% [markdown]
# # Modelling 20 :80

# %%
x = df.drop(['Churn'], axis=1)
y = df['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5,
                                       n_estimators=100, oob_score=True) 
RF.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
# Hyperparameter Tuning
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# %%
from sklearn.model_selection import GridSearchCV

# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 4,
                           n_jobs=-1, verbose=1, scoring="accuracy")

grid_search.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_score_
# Out:
# 0.9335585585585585

# %%
grid_search.best_params_
# Out:
# {'max_depth': 20, 'min_samples_leaf': 5, 'n_estimators': 25}

# %%
rf_best = grid_search.best_estimator_
rf_best.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=5, n_estimators=25,
#                        n_jobs=-1, random_state=42)

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
import pydotplus
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

dtree = tree.DecisionTreeClassifier()
dtree = dtree.fit(x_train, y_train)

# %%
text_representation = tree.export_text(dtree)
print(text_representation)
# Out:
# |--- feature_5 <= 264.45
# |   |--- feature_4 <= 3.50
# |   |   |--- feature_1 <= 0.50
# |   |   |   |--- feature_9 <= 13.10
# |   |   |   |   |--- feature_8 <= 11.56
# |   |   |   |   |   |--- feature_6 <= 48.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_6 >  48.00
# |   |   |   |   |   |   |--- feature_8 <= 9.52
# |   |   |   |   |   |   |   |--- feature_8 <= 9.03
# |   |   |   |   |   |   |   |   |--- feature_0 <= 172.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 70.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 48.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  48.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  70.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 7.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  7.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- feature_0 >  172.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 42.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  42.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  9.03
# |   |   |   |   |   |   |   |   |--- feature_8 <= 9.28
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  1.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  9.28
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 141.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 79.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  79.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  141.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  9.52
# |   |   |   |   |   |   |   |--- feature_9 <= 9.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_9 >  9.80
# |   |   |   |   |   |   |   |   |--- feature_9 <= 11.10
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 118.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 10.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  10.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  118.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_9 >  11.10
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  11.56
# |   |   |   |   |   |--- feature_7 <= 57.90
# |   |   |   |   |   |   |--- feature_6 <= 83.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_6 >  83.50
# |   |   |   |   |   |   |   |--- feature_6 <= 107.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_6 >  107.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 92.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.26
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.26
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  92.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  57.90
# |   |   |   |   |   |   |--- feature_0 <= 162.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 112.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 3.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  3.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_6 >  112.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  162.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_9 >  13.10
# |   |   |   |   |--- class: 1
# |   |   |--- feature_1 >  0.50
# |   |   |   |--- feature_5 <= 223.25
# |   |   |   |   |--- feature_8 <= 16.47
# |   |   |   |   |   |--- feature_5 <= 210.55
# |   |   |   |   |   |   |--- feature_7 <= 86.05
# |   |   |   |   |   |   |   |--- feature_7 <= 38.20
# |   |   |   |   |   |   |   |   |--- feature_0 <= 25.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 76.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  76.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  25.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 36.95
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 188.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  188.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  36.95
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 15.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  15.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  38.20
# |   |   |   |   |   |   |   |   |--- feature_6 <= 124.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 91.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 73.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  73.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  91.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 13.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  13.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- feature_6 >  124.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 146.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 10.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  10.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  146.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_7 >  86.05
# |   |   |   |   |   |   |   |--- feature_5 <= 175.30
# |   |   |   |   |   |   |   |   |--- feature_8 <= 13.04
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  13.04
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_5 >  175.30
# |   |   |   |   |   |   |   |   |--- feature_5 <= 201.30
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  201.30
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 201.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  201.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_5 >  210.55
# |   |   |   |   |   |   |--- feature_8 <= 13.80
# |   |   |   |   |   |   |   |--- feature_5 <= 213.95
# |   |   |   |   |   |   |   |   |--- feature_6 <= 129.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 66.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  66.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 12.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  12.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_6 >  129.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_5 >  213.95
# |   |   |   |   |   |   |   |   |--- feature_8 <= 10.98
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  10.98
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 11.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  11.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_8 >  13.80
# |   |   |   |   |   |   |   |--- feature_7 <= 66.10
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  66.10
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  16.47
# |   |   |   |   |   |--- feature_6 <= 115.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_6 >  115.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_5 >  223.25
# |   |   |   |   |--- feature_8 <= 12.99
# |   |   |   |   |   |--- feature_8 <= 12.03
# |   |   |   |   |   |   |--- feature_5 <= 223.40
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  223.40
# |   |   |   |   |   |   |   |--- feature_5 <= 259.35
# |   |   |   |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 10.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  10.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 109.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 108.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  108.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  109.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_5 >  259.35
# |   |   |   |   |   |   |   |   |--- feature_6 <= 138.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 259.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  259.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 81.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  81.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_6 >  138.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_8 >  12.03
# |   |   |   |   |   |   |--- feature_9 <= 13.05
# |   |   |   |   |   |   |   |--- feature_0 <= 108.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 124.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_6 >  124.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  108.00
# |   |   |   |   |   |   |   |   |--- feature_8 <= 12.84
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  12.84
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_9 >  13.05
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  12.99
# |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |--- feature_7 <= 62.50
# |   |   |   |   |   |   |   |--- feature_8 <= 13.61
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  13.61
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  62.50
# |   |   |   |   |   |   |   |--- feature_8 <= 13.37
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  13.37
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- feature_4 >  3.50
# |   |   |--- feature_7 <= 45.95
# |   |   |   |--- feature_0 <= 207.00
# |   |   |   |   |--- feature_0 <= 46.50
# |   |   |   |   |   |--- feature_6 <= 102.50
# |   |   |   |   |   |   |--- feature_5 <= 115.80
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  115.80
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_6 >  102.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  46.50
# |   |   |   |   |   |--- feature_5 <= 159.70
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_5 >  159.70
# |   |   |   |   |   |   |--- feature_8 <= 9.53
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  9.53
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_0 >  207.00
# |   |   |   |   |--- class: 0
# |   |   |--- feature_7 >  45.95
# |   |   |   |--- feature_5 <= 160.20
# |   |   |   |   |--- feature_8 <= 13.10
# |   |   |   |   |   |--- feature_5 <= 143.90
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_5 >  143.90
# |   |   |   |   |   |   |--- feature_4 <= 4.50
# |   |   |   |   |   |   |   |--- feature_9 <= 13.55
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_9 >  13.55
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  4.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  13.10
# |   |   |   |   |   |--- feature_8 <= 15.57
# |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  15.57
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_5 >  160.20
# |   |   |   |   |--- feature_8 <= 6.76
# |   |   |   |   |   |--- feature_5 <= 236.95
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_5 >  236.95
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  6.76
# |   |   |   |   |   |--- feature_6 <= 133.50
# |   |   |   |   |   |   |--- feature_4 <= 8.50
# |   |   |   |   |   |   |   |--- feature_8 <= 17.49
# |   |   |   |   |   |   |   |   |--- feature_5 <= 188.15
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 10.62
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 106.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  106.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  10.62
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  188.15
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 8.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  8.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  17.49
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  8.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_6 >  133.50
# |   |   |   |   |   |   |--- class: 1
# |--- feature_5 >  264.45
# |   |--- feature_2 <= 0.50
# |   |   |--- feature_7 <= 62.50
# |   |   |   |--- feature_9 <= 17.15
# |   |   |   |   |--- feature_0 <= 167.50
# |   |   |   |   |   |--- feature_6 <= 91.00
# |   |   |   |   |   |   |--- feature_0 <= 100.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  100.50
# |   |   |   |   |   |   |   |--- feature_9 <= 10.65
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  10.65
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_6 >  91.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  167.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_9 >  17.15
# |   |   |   |   |--- class: 1
# |   |   |--- feature_7 >  62.50
# |   |   |   |--- feature_7 <= 64.90
# |   |   |   |   |--- feature_0 <= 101.50
# |   |   |   |   |   |--- feature_7 <= 64.45
# |   |   |   |   |   |   |--- feature_5 <= 293.40
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  293.40
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  64.45
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  101.50
# |   |   |   |   |   |--- feature_5 <= 275.60
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_5 >  275.60
# |   |   |   |   |   |   |--- feature_0 <= 113.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  113.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_7 >  64.90
# |   |   |   |   |--- feature_3 <= 0.09
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  0.09
# |   |   |   |   |   |--- feature_3 <= 0.28
# |   |   |   |   |   |   |--- feature_7 <= 68.60
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_7 >  68.60
# |   |   |   |   |   |   |   |--- feature_3 <= 0.20
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  0.20
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  0.28
# |   |   |   |   |   |   |--- class: 1
# |   |--- feature_2 >  0.50
# |   |   |--- feature_1 <= 0.50
# |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |--- class: 1
# |   |   |--- feature_1 >  0.50
# |   |   |   |--- feature_5 <= 318.10
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_5 >  318.10
# |   |   |   |   |--- class: 1

# %% [markdown]
# # Evaluation Model

# %%
#Evaluation
RF_pred= RF.predict(x_test)
dtree_pred = dtree.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, RF_pred))
print(confusion_matrix(y_test, dtree_pred))
# Out:
# [[579   5]
#  [ 29  53]]
# [[552  32]
#  [ 26  56]]

# %%
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test,RF_pred), annot=True, fmt=".0f", ax=ax)
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test, dtree_pred), annot=True, fmt=".0f", ax=ax)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, RF_pred, pos_label=1) # pos_label: positive label
print(auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test, dtree_pred, pos_label=1) # pos_label: positive label
print(auc(fpr, tpr))
# Out:
# 0.8188899097895089
# 0.8140661543601738

# %%
from sklearn.metrics import classification_report, accuracy_score
print(classification_report(y_test,RF_pred )) 
print(accuracy_score(y_test, RF_pred ))

print(classification_report(y_test,dtree_pred )) 
print(accuracy_score(y_test, dtree_pred ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       584
#            1       0.91      0.65      0.76        82
#
#     accuracy                           0.95       666
#    macro avg       0.93      0.82      0.86       666
# weighted avg       0.95      0.95      0.95       666
#
# 0.948948948948949
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       584
#            1       0.64      0.68      0.66        82
#
#     accuracy                           0.91       666
#    macro avg       0.80      0.81      0.80       666
# weighted avg       0.92      0.91      0.91       666
#
# 0.9129129129129129

# %% [markdown]
# Hasil akurasi dengan menggunakan metode random forest menunjukkan angka sebesar 95%. Sedangkan dengan menggunakan metode decision tree menghasilkan nilai akurasi sebesar 92%. Oleh karena itu, dapat dikatakan bahwa metode random forest lebih baik dibandingkan metode decision tree

# %% [markdown]
# # Modelling 15:85

# %%
x = df.drop(['Churn'], axis=1)
y = df['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 0)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5,
                                       n_estimators=100, oob_score=True) 
RF.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
# Hyperparameter Tuning
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# %%
from sklearn.model_selection import GridSearchCV

# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 4,
                           n_jobs=-1, verbose=1, scoring="accuracy")

grid_search.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits

# %%
grid_search.best_score_

# %%
grid_search.best_params_

# %%
rf_best = grid_search.best_estimator_
rf_best.fit(x_train, y_train)

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
import pydotplus
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

dtree = tree.DecisionTreeClassifier()
dtree = dtree.fit(x_train, y_train)

# %%
text_representation = tree.export_text(dtree)
print(text_representation)

# %% [markdown]
# # Evaluation Model

# %%
#Evaluation
RF_pred= RF.predict(x_test)
dtree_pred = dtree.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, RF_pred))
print(confusion_matrix(y_test, dtree_pred))

# %%
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test,RF_pred), annot=True, fmt=".0f", ax=ax)

# %%
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test, dtree_pred), annot=True, fmt=".0f", ax=ax)

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, RF_pred, pos_label=1) # pos_label: positive label
print(auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test, dtree_pred, pos_label=1) # pos_label: positive label
print(auc(fpr, tpr))

# %%
from sklearn.metrics import classification_report, accuracy_score
print(classification_report(y_test,RF_pred )) 
print(accuracy_score(y_test, RF_pred ))

print(classification_report(y_test,dtree_pred )) 
print(accuracy_score(y_test, dtree_pred ))

# %% [markdown]
# Hasil akurasi dengan menggunakan metode random forest menunjukkan angka sebesar 94%. Sedangkan dengan menggunakan metode decision tree menghasilkan nilai akurasi sebesar 89%. Oleh karena itu, dapat dikatakan bahwa metode random forest lebih baik dibandingkan metode decision tree

# %% [markdown]
# # Modelling 10:90

# %%
x = df.drop(['Churn'], axis=1)
y = df['Churn']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 0)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5,
                                       n_estimators=100, oob_score=True) 
RF.fit(x_train, y_train)

# %%
# Hyperparameter Tuning
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# %%
from sklearn.model_selection import GridSearchCV

# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 4,
                           n_jobs=-1, verbose=1, scoring="accuracy")

grid_search.fit(x_train, y_train)

# %%
grid_search.best_score_

# %%
grid_search.best_params_

# %%
rf_best = grid_search.best_estimator_
rf_best.fit(x_train, y_train)

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
import pydotplus
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

dtree = tree.DecisionTreeClassifier()
dtree = dtree.fit(x_train, y_train)

# %%
text_representation = tree.export_text(dtree)
print(text_representation)

# %% [markdown]
# # Evaluation Model

# %%
#Evaluation
RF_pred= RF.predict(x_test)
dtree_pred = dtree.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, RF_pred))
print(confusion_matrix(y_test, dtree_pred))

# %%
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test,RF_pred), annot=True, fmt=".0f", ax=ax)

# %%
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test, dtree_pred), annot=True, fmt=".0f", ax=ax)

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, RF_pred, pos_label=1) # pos_label: positive label
print(auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test, dtree_pred, pos_label=1) # pos_label: positive label
print(auc(fpr, tpr))

# %%
from sklearn.metrics import classification_report, accuracy_score
print(classification_report(y_test,RF_pred )) 
print(accuracy_score(y_test, RF_pred ))

print(classification_report(y_test,dtree_pred )) 
print(accuracy_score(y_test, dtree_pred ))

# %% [markdown]
# Hasil akurasi dengan menggunakan metode random forest menunjukkan angka sebesar 95%. Sedangkan dengan menggunakan metode decision tree menghasilkan nilai akurasi sebesar 89%. Oleh karena itu, dapat dikatakan bahwa metode random forest lebih baik dibandingkan metode decision tree

# %% [markdown]
# ##Faktor-faktor yang mempengaruhi churn

# %%
#Feature Importance
tree_feature =  pd.Series(RF.feature_importances_, x.columns).sort_values(ascending = True)
plt.figure(figsize = (8,8))
plt.barh(x.columns, tree_feature)
plt.xlabel('Mean Impurity Reduction', fontsize = 12)
plt.ylabel('Features', fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Feature Importances', fontsize = 20)

# %% [markdown]
# Dapat diketahui faktor-faktor yang mempengaruhi churn dari yang terbesar sampai terkecil yaitu RoamMins, OverageFee, MonthlyCharge, DayCalls, DayMins, CustServCalls, DataUsage, Data Plan, ContactRenewal, dan AccountWeeks.
